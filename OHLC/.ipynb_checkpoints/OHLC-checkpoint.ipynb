# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import datetime
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense, Activation, Dropout, LSTM
from tensorflow.keras import Sequential
from sklearn.model_selection import  train_test_split

from timeanalysis import Timeseries

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# **Apple**

# %%
aapl  = pd.read_csv('Data/AAPL_Historic_Prices.csv')
Timeseries.plot_ohlc_candlestick(aapl,'Date','Open','High','Low','Close')
Timeseries.plot_ohlc_line(aapl,'Date','Open','High','Low','Close')
Timeseries.test_stationarity(aapl,'Date','Close',30)
# Out:
# <div>
#
#
#             <div id="3953570c-961b-4c55-aab2-3a63944cd3a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3953570c-961b-4c55-aab2-3a63944cd3a2")) {
#                     Plotly.newPlot(
#                         '3953570c-961b-4c55-aab2-3a63944cd3a2',
#                         [{"close": [116.150002, 116.019997, 116.610001, 117.910004, 118.989998, 119.110001, 119.75, 119.25, 119.040001, 120.0, 119.989998, 119.779999, 120.0, 120.08000200000001, 119.970001, 121.879997, 121.940002, 121.949997, 121.629997, 121.349998, 128.75, 128.529999, 129.080002, 130.28999299999998, 131.529999, 132.03999299999998, 132.419998, 132.119995, 133.28999299999998, 135.020004, 135.509995, 135.350006, 135.720001, 136.699997, 137.110001, 136.529999, 136.66000400000001, 136.929993, 136.990005, 139.78999299999998, 138.96000700000002, 139.779999, 139.33999599999999, 139.520004, 139.0, 138.679993, 139.139999, 139.199997, 138.990005, 140.46000700000002, 140.690002, 139.990005, 141.46000700000002, 139.83999599999999, 141.419998, 140.919998, 140.639999, 140.880005, 143.800003, 144.119995, 143.929993, 143.66000400000001, 143.699997, 144.770004, 144.020004, 143.66000400000001, 143.33999599999999, 143.169998, 141.630005, 141.800003, 141.050003, 141.830002, 141.199997, 140.679993, 142.440002, 142.270004, 143.639999, 144.529999, 143.679993, 143.78999299999998, 143.649994, 146.580002, 147.509995, 147.059998, 146.529999, 148.96000700000002, 153.009995, 153.990005, 153.259995, 153.949997, 156.100006, 155.699997, 155.470001, 150.25, 152.53999299999998, 153.059998, 153.990005, 153.800003, 153.33999599999999, 153.869995, 153.610001, 153.669998, 152.759995, 153.179993, 155.449997, 153.929993, 154.449997, 155.369995, 154.990005, 148.979996, 145.419998, 146.58999599999999, 145.16000400000001, 144.28999299999998, 142.270004, 146.33999599999999, 145.009995, 145.869995, 145.630005, 146.279999, 145.820007, 143.729996, 145.830002, 143.679993, 144.020004, 143.5, 144.08999599999999, 142.729996, 144.179993, 145.059998, 145.529999, 145.740005, 147.770004, 149.03999299999998, 149.559998, 150.080002, 151.020004, 150.33999599999999, 150.270004, 152.08999599999999, 152.740005, 153.46000700000002, 150.559998, 149.5, 148.729996, 150.050003, 157.139999, 155.570007, 156.389999, 158.809998, 160.080002, 161.059998, 155.320007, 157.479996, 159.850006, 161.600006, 160.949997, 157.860001, 157.5, 157.21000700000002, 159.779999, 159.979996, 159.270004, 159.860001, 161.470001, 162.91000400000001, 163.350006, 164.0, 164.050003, 162.080002, 161.91000400000001, 161.259995, 158.630005, 161.5, 160.860001, 159.649994, 158.279999, 159.880005, 158.669998, 158.729996, 156.070007, 153.389999, 151.889999, 150.550003, 153.139999, 154.229996, 153.279999, 154.119995, 153.809998, 154.479996, 153.479996, 155.389999, 155.300003, 155.83999599999999, 155.899994, 156.550003, 156.0, 156.990005, 159.880005, 160.470001, 159.759995, 155.979996, 156.25, 156.169998, 157.100006, 156.41000400000001, 157.41000400000001, 163.050003, 166.720001, 169.03999299999998, 166.889999, 168.110001, 172.5, 174.25, 174.809998, 176.240005, 175.880005, 174.669998, 173.970001, 171.33999599999999, 169.080002, 171.100006, 170.149994, 169.979996, 173.139999, 174.96000700000002, 174.970001, 174.08999599999999, 173.070007, 169.479996, 171.850006, 171.050003, 169.800003, 169.639999, 169.009995, 169.320007, 169.369995, 172.669998, 171.699997, 172.270004, 172.220001, 173.970001, 176.419998, 174.53999299999998, 174.350006, 175.009995, 175.009995, 170.570007, 170.600006, 171.080002, 169.229996, 172.259995, 172.229996, 173.029999, 175.0, 174.350006, 174.330002, 174.28999299999998, 175.279999, 177.08999599999999, 176.190002, 179.100006, 179.259995, 178.46000700000002, 177.0, 177.03999299999998, 174.220001, 171.110001, 171.509995, 167.96000700000002, 166.970001, 167.429993, 167.779999, 160.5, 156.490005, 163.029999, 159.53999299999998, 155.149994, 156.41000400000001, 162.71000700000002, 164.33999599999999, 167.369995, 172.990005, 172.429993, 171.850006, 171.070007, 172.5, 175.5, 178.970001, 178.389999, 178.119995, 175.0, 176.21000700000002, 176.820007, 176.669998, 175.029999, 176.940002, 179.979996, 181.720001, 179.970001, 178.440002, 178.649994, 178.020004, 175.300003, 175.240005, 171.270004, 168.850006,  ...
# <div>
#
#
#             <div id="78e77f8f-18d7-451e-98d8-96d8f93c8a4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("78e77f8f-18d7-451e-98d8-96d8f93c8a4e")) {
#                     Plotly.newPlot(
#                         '78e77f8f-18d7-451e-98d8-96d8f93c8a4e',
#                         [{"line": {"color": "#0EB0F2"}, "name": "Open", "opacity": 0.8, "type": "scatter", "uid": "25c58e34-6356-4019-a62d-3071283f2130", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "201 ...
# <div>
#
#
#             <div id="3ebba231-1025-4c63-bf26-cb644aed4b36" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3ebba231-1025-4c63-bf26-cb644aed4b36")) {
#                     Plotly.newPlot(
#                         '3ebba231-1025-4c63-bf26-cb644aed4b36',
#                         [{"line": {"color": "#17BECF"}, "name": "Rolling Mean", "opacity": 0.8, "type": "scatter", "uid": "791e163a-7841-4ba3-8a3d-6d136b86248d", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-0 ...
# ******************************
# H0: Not Stationary
# H1: Stationary
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.001412
# p-value                          0.285954
# #Lags Used                       8.000000
# Number of Observations Used    493.000000
# Critical Value (1%)             -3.443684
# Critical Value (5%)             -2.867420
# Critical Value (10%)            -2.569902
# dtype: float64
# ******************************
# H0: Stationary
# H1: Not Stationary
# Results of KPSS Test:
# Test Statistic            2.147804
# p-value                   0.010000
# Lags Used                18.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# C:\Users\Ravi.RAVI-DRAGOON\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\stattools.py:1276: InterpolationWarning:
#
# p-value is smaller than the indicated p-value

# %%
stock = aapl['Close'].values.astype('float32')
stock = stock.reshape(502, 1)
stock.shape
# Out:
# (502, 1)

# %%
plt.plot(stock)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
stock = scaler.fit_transform(stock)

# %%
train_size = int(len(stock) * 0.80)
test_size = len(stock) - train_size
train, test = stock[0:train_size,:], stock[train_size:len(stock),:]
print(len(train), len(test))
# Out:
# 401 101

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
look_back = 7
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
(trainX.shape,trainY.shape),(testX.shape,testY.shape)
# Out:
# (((394, 7), (394,)), ((94, 7), (94,)))

# %%
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1],1))

# %%
trainX.shape
# Out:
# (394, 7, 1)

# %%
model = Sequential()

model.add(LSTM(50, activation='relu', input_shape=(trainX.shape[1],1) ,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(100,activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50,activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(20,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='relu'))
model.summary()
model.compile(loss='mse', optimizer='rmsprop',metrics=['mse'])
history = model.fit(trainX,trainY,epochs=5,batch_size=7,validation_data=(testX,testY),shuffle=False)
pred = model.predict(testX)
plt.plot(testY)
plt.plot(pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 7, 50)             10400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 50)             0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 7, 100)            60400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 100)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 7, 50)             30200
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 7, 50)             0
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 20)                5680
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 106,701
# Trainable params: 106,701
# Non-trainable params: 0
# _________________________________________________________________
# Train on 394 samples, validate on 94 samples
# Epoch 1/5
# 394/394 [==============================] - 8s 20ms/sample - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0474 - val_mean_squared_error: 0.0474
# Epoch 2/5
# 394/394 [==============================] - 6s 14ms/sample - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.1296 - val_mean_squared_error: 0.1296
# Epoch 3/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0191 - val_mean_squared_error: 0.0191
# Epoch 4/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 5/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.1993 - val_mean_squared_error: 0.1993

# %% [markdown]
# **Facebook**

# %%
fb  = pd.read_csv('Data/FB_Historic_Prices.csv')
Timeseries.plot_ohlc_candlestick(fb,'Date','Open','High','Low','Close')
Timeseries.plot_ohlc_line(fb,'Date','Open','High','Low','Close')
Timeseries.test_stationarity(fb,'Date','Close',30)
# Out:
# <div>
#
#
#             <div id="c1d286ef-0cec-48bf-b2a9-0ebd383f37ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c1d286ef-0cec-48bf-b2a9-0ebd383f37ca")) {
#                     Plotly.newPlot(
#                         'c1d286ef-0cec-48bf-b2a9-0ebd383f37ca',
#                         [{"close": [116.860001, 118.690002, 120.66999799999999, 123.410004, 124.900002, 124.349998, 126.089996, 126.620003, 128.33999599999999, 127.870003, 127.91999799999999, 127.550003, 127.040001, 128.929993, 129.369995, 131.479996, 132.779999, 132.179993, 130.979996, 130.320007, 133.229996, 130.83999599999999, 130.979996, 132.059998, 131.83999599999999, 134.199997, 134.139999, 134.190002, 134.050003, 133.850006, 133.440002, 133.83999599999999, 133.529999, 133.720001, 136.119995, 135.360001, 135.440002, 136.41000400000001, 135.53999299999998, 137.419998, 136.759995, 137.169998, 137.419998, 137.300003, 137.720001, 138.240005, 138.78999299999998, 139.600006, 139.320007, 139.720001, 139.990005, 139.83999599999999, 139.940002, 138.509995, 139.58999599999999, 139.529999, 140.33999599999999, 140.320007, 141.759995, 142.649994, 142.41000400000001, 142.050003, 142.279999, 141.729996, 141.850006, 141.169998, 140.779999, 141.03999299999998, 139.919998, 139.580002, 139.389999, 141.419998, 140.96000700000002, 142.270004, 143.800003, 143.679993, 145.470001, 146.490005, 146.559998, 147.699997, 150.25, 152.46000700000002, 152.779999, 151.800003, 150.850006, 150.240005, 151.059998, 150.479996, 150.28999299999998, 150.03999299999998, 150.330002, 150.190002, 149.779999, 144.850006, 147.66000400000001, 148.059998, 148.240005, 148.070007, 150.03999299999998, 151.96000700000002, 152.130005, 152.380005, 151.46000700000002, 151.529999, 153.610001, 153.630005, 152.809998, 153.119995, 154.71000700000002, 149.600006, 148.440002, 150.679993, 150.25, 149.800003, 150.639999, 152.869995, 152.25, 153.91000400000001, 153.399994, 155.070007, 153.58999599999999, 150.580002, 153.240005, 151.03999299999998, 150.979996, 148.429993, 150.33999599999999, 148.820007, 151.440002, 153.5, 155.270004, 158.899994, 159.259995, 159.970001, 159.729996, 162.860001, 164.139999, 164.529999, 164.429993, 166.0, 165.279999, 165.610001, 170.440002, 172.449997, 169.25, 169.860001, 169.300003, 168.58999599999999, 169.619995, 171.979996, 171.229996, 171.179993, 167.399994, 168.080002, 170.75, 171.0, 170.0, 166.91000400000001, 167.41000400000001, 167.779999, 169.639999, 168.71000700000002, 167.740005, 166.320007, 167.240005, 168.050003, 169.919998, 171.970001, 172.020004, 170.720001, 172.08999599999999, 173.21000700000002, 170.949997, 173.509995, 172.96000700000002, 173.050003, 170.96000700000002, 171.639999, 170.009995, 172.520004, 172.169998, 171.110001, 170.53999299999998, 162.869995, 164.21000700000002, 167.679993, 168.729996, 170.869995, 169.470001, 169.96000700000002, 168.419998, 171.240005, 172.229996, 172.5, 171.58999599999999, 172.740005, 172.550003, 173.740005, 174.520004, 176.110001, 176.029999, 174.559998, 174.979996, 171.270004, 171.800003, 170.600006, 170.630005, 177.880005, 179.869995, 180.059998, 182.66000400000001, 178.919998, 178.919998, 180.169998, 180.25, 179.559998, 179.300003, 178.46000700000002, 178.770004, 178.070007, 177.949997, 179.58999599999999, 179.0, 178.740005, 181.860001, 180.869995, 182.779999, 183.029999, 182.419998, 175.130005, 177.179993, 175.100006, 171.470001, 172.830002, 176.059998, 180.139999, 179.0, 179.03999299999998, 176.96000700000002, 178.300003, 178.389999, 180.179993, 180.820007, 179.509995, 177.889999, 177.449997, 177.199997, 175.990005, 177.619995, 177.919998, 176.46000700000002, 181.419998, 184.669998, 184.330002, 186.850006, 188.279999, 187.869995, 187.83999599999999, 187.770004, 179.369995, 178.389999, 177.600006, 179.800003, 181.28999299999998, 185.369995, 189.350006, 186.550003, 187.479996, 190.0, 185.979996, 187.119995, 186.889999, 193.08999599999999, 190.279999, 181.259995, 185.309998, 180.179993, 171.580002, 176.110001, 176.41000400000001, 173.149994, 179.520004, 179.96000700000002, 177.360001, 176.009995, 177.91000400000001, 178.990005, 183.28999299999998, 184.929993, 181.46000700000002, 178.320007, 175.940002, 176.619995, 180.399994, 179.779999, 183.71000700000002, 182.33999599999999, 185.229996, 184.759995,  ...
# <div>
#
#
#             <div id="79061ca8-65b0-4f5d-8a7e-541900d44553" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("79061ca8-65b0-4f5d-8a7e-541900d44553")) {
#                     Plotly.newPlot(
#                         '79061ca8-65b0-4f5d-8a7e-541900d44553',
#                         [{"line": {"color": "#0EB0F2"}, "name": "Open", "opacity": 0.8, "type": "scatter", "uid": "5edc95a4-c51d-414e-8b75-8c25e5feeb40", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "201 ...
# <div>
#
#
#             <div id="f22eea81-82d8-402f-8dda-ddb3951ee313" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f22eea81-82d8-402f-8dda-ddb3951ee313")) {
#                     Plotly.newPlot(
#                         'f22eea81-82d8-402f-8dda-ddb3951ee313',
#                         [{"line": {"color": "#17BECF"}, "name": "Rolling Mean", "opacity": 0.8, "type": "scatter", "uid": "b8b9e090-22bb-424f-a611-7cec31dff3e9", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-0 ...
# ******************************
# H0: Not Stationary
# H1: Stationary
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.212603
# p-value                          0.201703
# #Lags Used                       0.000000
# Number of Observations Used    501.000000
# Critical Value (1%)             -3.443470
# Critical Value (5%)             -2.867326
# Critical Value (10%)            -2.569852
# dtype: float64
# ******************************
# H0: Stationary
# H1: Not Stationary
# Results of KPSS Test:
# Test Statistic            0.897977
# p-value                   0.010000
# Lags Used                18.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# C:\Users\Ravi.RAVI-DRAGOON\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\stattools.py:1276: InterpolationWarning:
#
# p-value is smaller than the indicated p-value

# %%
stock = fb['Close'].values.astype('float32')
stock = stock.reshape(502, 1)
stock.shape
# Out:
# (502, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
stock = scaler.fit_transform(stock)
train_size = int(len(stock) * 0.80)
test_size = len(stock) - train_size
train, test = stock[0:train_size,:], stock[train_size:len(stock),:]
print(len(train), len(test))
look_back = 7
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
(trainX.shape,trainY.shape),(testX.shape,testY.shape)
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1],1))
# Out:
# 401 101

# %%
model = Sequential()

model.add(LSTM(50, activation='relu', input_shape=(trainX.shape[1],1) ,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(100,activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50,activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(20,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='relu'))
model.summary()
model.compile(loss='mse', optimizer='rmsprop',metrics=['mse'])
history = model.fit(trainX,trainY,epochs=5,batch_size=7,validation_data=(testX,testY),shuffle=False)
pred = model.predict(testX)
plt.plot(testY)
plt.plot(pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 7, 50)             10400
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 7, 50)             0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 7, 100)            60400
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 7, 100)            0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 7, 50)             30200
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 7, 50)             0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 20)                5680
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 106,701
# Trainable params: 106,701
# Non-trainable params: 0
# _________________________________________________________________
# Train on 394 samples, validate on 94 samples
# Epoch 1/5
# 394/394 [==============================] - 8s 20ms/sample - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 2/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# Epoch 3/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 4/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 5/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0209 - val_mean_squared_error: 0.0209

# %% [markdown]
# **Amazon**

# %%
amzn  = pd.read_csv('Data/AMZN_Historic_Prices.csv')
Timeseries.plot_ohlc_candlestick(amzn,'Date','Open','High','Low','Close')
Timeseries.plot_ohlc_line(amzn,'Date','Open','High','Low','Close')
Timeseries.test_stationarity(amzn,'Date','Close',30)
# Out:
# <div>
#
#
#             <div id="02f9bc36-9612-4837-af8c-bac08b880322" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("02f9bc36-9612-4837-af8c-bac08b880322")) {
#                     Plotly.newPlot(
#                         '02f9bc36-9612-4837-af8c-bac08b880322',
#                         [{"close": [753.669983, 757.179993, 780.450012, 795.98999, 796.919983, 795.900024, 799.02002, 813.6400150000001, 817.1400150000001, 809.719971, 807.47998, 809.039978, 808.330017, 817.880005, 822.4400019999999, 836.52002, 839.150024, 835.77002, 830.380005, 823.47998, 832.349976, 839.9500119999999, 810.200012, 807.6400150000001, 812.5, 819.710022, 821.3599849999999, 827.460022, 836.530029, 836.3900150000001, 842.7000119999999, 844.1400150000001, 845.070007, 856.4400019999999, 855.6099849999999, 852.1900019999999, 845.23999, 848.6400150000001, 845.0399779999999, 853.080017, 848.909973, 849.8800050000001, 846.6099849999999, 846.0200199999999, 850.5, 853.0, 852.4600220000001, 854.590027, 852.5300289999999, 852.9699710000001, 853.419983, 852.3099980000001, 856.9699710000001, 843.2000119999999, 848.0599980000001, 847.3800050000001, 845.6099849999999, 846.820007, 856.0, 874.320007, 876.340027, 886.5399779999999, 891.51001, 906.830017, 909.2800289999999, 898.2800289999999, 894.8800050000001, 907.0399779999999, 902.3599849999999, 896.2299800000001, 884.669983, 901.98999, 903.7800289999999, 899.2000119999999, 902.0599980000001, 898.5300289999999, 907.409973, 907.6199949999999, 909.2899779999999, 918.3800050000001, 924.98999, 948.2299800000001, 946.9400019999999, 941.0300289999999, 937.5300289999999, 934.150024, 949.0399779999999, 952.820007, 948.9500119999999, 947.6199949999999, 961.349976, 957.9699710000001, 966.070007, 944.76001, 958.48999, 959.840027, 970.669983, 971.5399779999999, 980.349976, 993.3800050000001, 995.7800289999999, 996.7000119999999, 994.6199949999999, 995.9500119999999, 1006.7299800000001, 1011.340027, 1003.0, 1010.070007, 1010.2700199999999, 978.3099980000001, 964.909973, 980.7899779999999, 976.4699710000001, 964.169983, 987.7100220000001, 995.169983, 992.590027, 1002.2299800000001, 1001.2999880000001, 1003.73999, 993.9799800000001, 976.7800289999999, 990.330017, 975.929993, 968.0, 953.659973, 971.400024, 965.1400150000001, 978.76001, 996.4699710000001, 994.1300050000001, 1006.51001, 1000.6300050000001, 1001.8099980000001, 1010.0399779999999, 1024.449951, 1026.869995, 1028.699951, 1025.670044, 1038.949951, 1039.869995, 1052.800049, 1046.0, 1020.0399779999999, 987.7800289999999, 996.1900019999999, 995.8900150000001, 986.919983, 987.580017, 992.2700199999999, 989.840027, 982.01001, 956.919983, 967.98999, 983.2999880000001, 982.73999, 978.179993, 960.570007, 958.4699710000001, 953.2899779999999, 966.900024, 958.0, 952.4500119999999, 945.26001, 946.0200199999999, 954.0599980000001, 967.590027, 980.599976, 978.25, 965.2700199999999, 967.7999880000001, 979.4699710000001, 965.900024, 977.9600220000001, 982.580017, 999.599976, 992.2100220000001, 986.7899779999999, 974.1900019999999, 969.8599849999999, 973.2100220000001, 964.650024, 955.099976, 939.7899779999999, 938.599976, 950.8699949999999, 956.400024, 961.349976, 959.1900019999999, 957.099976, 965.4500119999999, 980.849976, 989.580017, 990.98999, 987.2000119999999, 995.0, 1000.929993, 1002.9400019999999, 1006.340027, 1009.1300050000001, 997.0, 986.6099849999999, 982.909973, 966.2999880000001, 975.900024, 972.909973, 972.429993, 1100.949951, 1110.849976, 1105.280029, 1103.680054, 1094.219971, 1111.599976, 1120.660034, 1123.170044, 1132.880005, 1129.130005, 1125.349976, 1129.170044, 1136.839966, 1126.689941, 1137.290039, 1129.880005, 1126.310059, 1139.48999, 1156.160034, 1186.0, 1195.829956, 1193.599976, 1161.27002, 1176.75, 1162.349976, 1133.949951, 1141.569946, 1152.349976, 1159.790039, 1162.0, 1168.920044, 1165.079956, 1164.130005, 1174.26001, 1179.140015, 1190.579956, 1187.380005, 1177.619995, 1174.76001, 1168.359985, 1176.76001, 1182.26001, 1186.099976, 1169.469971, 1189.01001, 1204.199951, 1209.589966, 1229.140015, 1246.869995, 1252.699951, 1254.329956, 1276.680054, 1305.199951, 1304.859985, 1295.0, 1293.319946, 1294.579956, 1327.310059, 1362.540039, 1357.51001, 1377.949951, 1402.050049, 1417.680054, 1437.819946, 1450.890015, 1390.0, 1429.94995 ...
# <div>
#
#
#             <div id="974ac55b-c803-4a58-bae5-283a78565b47" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("974ac55b-c803-4a58-bae5-283a78565b47")) {
#                     Plotly.newPlot(
#                         '974ac55b-c803-4a58-bae5-283a78565b47',
#                         [{"line": {"color": "#0EB0F2"}, "name": "Open", "opacity": 0.8, "type": "scatter", "uid": "958c3392-e30a-42a8-b72e-e5ef5fdc9e3e", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "201 ...
# <div>
#
#
#             <div id="bb476503-9fbc-4641-a8d8-c8d95082982b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("bb476503-9fbc-4641-a8d8-c8d95082982b")) {
#                     Plotly.newPlot(
#                         'bb476503-9fbc-4641-a8d8-c8d95082982b',
#                         [{"line": {"color": "#17BECF"}, "name": "Rolling Mean", "opacity": 0.8, "type": "scatter", "uid": "a973f96b-42b8-4f15-8285-897c8a66c68a", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-0 ...
# ******************************
# H0: Not Stationary
# H1: Stationary
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.300977
# p-value                          0.628725
# #Lags Used                      18.000000
# Number of Observations Used    483.000000
# Critical Value (1%)             -3.443962
# Critical Value (5%)             -2.867543
# Critical Value (10%)            -2.569967
# dtype: float64
# ******************************
# H0: Stationary
# H1: Not Stationary
# Results of KPSS Test:
# Test Statistic            2.509567
# p-value                   0.010000
# Lags Used                18.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# C:\Users\Ravi.RAVI-DRAGOON\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\stattools.py:1276: InterpolationWarning:
#
# p-value is smaller than the indicated p-value

# %%
stock = amzn['Close'].values.astype('float32')
stock = stock.reshape(502, 1)
stock.shape
# Out:
# (502, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
stock = scaler.fit_transform(stock)
train_size = int(len(stock) * 0.80)
test_size = len(stock) - train_size
train, test = stock[0:train_size,:], stock[train_size:len(stock),:]
print(len(train), len(test))
look_back = 7
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
(trainX.shape,trainY.shape),(testX.shape,testY.shape)
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1],1))
# Out:
# 401 101

# %%
model = Sequential()

model.add(LSTM(50, activation='relu', input_shape=(trainX.shape[1],1) ,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(100,activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50,activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(20,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='relu'))
model.summary()
model.compile(loss='mse', optimizer='rmsprop',metrics=['mse'])
history = model.fit(trainX,trainY,epochs=5,batch_size=7,validation_data=(testX,testY),shuffle=False)
pred = model.predict(testX)
plt.plot(testY)
plt.plot(pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 7, 50)             10400
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 7, 50)             0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 7, 100)            60400
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 7, 100)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 7, 50)             30200
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 7, 50)             0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 20)                5680
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 106,701
# Trainable params: 106,701
# Non-trainable params: 0
# _________________________________________________________________
# Train on 394 samples, validate on 94 samples
# Epoch 1/5
# 394/394 [==============================] - 9s 23ms/sample - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
# Epoch 2/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
# Epoch 3/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# Epoch 4/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# Epoch 5/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0117 - val_mean_squared_error: 0.0117

# %% [markdown]
# **Google**

# %%
googl  = pd.read_csv('Data/GOOG_Historic_Prices.csv')
Timeseries.plot_ohlc_candlestick(googl,'Date','Open','High','Low','Close')
Timeseries.plot_ohlc_line(googl,'Date','Open','High','Low','Close')
Timeseries.test_stationarity(googl,'Date','Close',30)
# Out:
# <div>
#
#
#             <div id="d3a70279-12a9-46ca-9f80-4cb716bd0e77" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d3a70279-12a9-46ca-9f80-4cb716bd0e77")) {
#                     Plotly.newPlot(
#                         'd3a70279-12a9-46ca-9f80-4cb716bd0e77',
#                         [{"close": [786.1400150000001, 786.900024, 794.02002, 806.150024, 806.650024, 804.789978, 807.909973, 806.3599849999999, 807.880005, 804.6099849999999, 806.070007, 802.174988, 805.02002, 819.3099980000001, 823.869995, 835.669983, 832.150024, 823.3099980000001, 802.320007, 796.789978, 795.695007, 798.530029, 801.48999, 801.340027, 806.969971, 808.380005, 809.5599980000001, 813.669983, 819.23999, 820.450012, 818.97998, 824.159973, 828.070007, 831.659973, 830.76001, 831.330017, 828.6400150000001, 829.280029, 823.210022, 835.23999, 830.630005, 829.080017, 827.780029, 831.909973, 835.369995, 838.679993, 843.25, 845.5399779999999, 845.6199949999999, 847.2000119999999, 848.7800289999999, 852.1199949999999, 848.400024, 830.460022, 829.590027, 817.580017, 814.429993, 819.51001, 820.919983, 831.409973, 831.5, 829.5599980000001, 838.549988, 834.570007, 831.409973, 827.880005, 824.669983, 824.72998, 823.349976, 824.320007, 823.5599980000001, 837.169983, 836.820007, 838.210022, 841.650024, 843.1900019999999, 862.76001, 872.2999880000001, 871.7299800000001, 874.25, 905.9600220000001, 912.570007, 916.4400019999999, 927.0399779999999, 931.659973, 927.1300050000001, 934.2999880000001, 932.169983, 928.7800289999999, 930.599976, 932.2199710000001, 937.080017, 943.0, 919.6199949999999, 930.23999, 934.01001, 941.8599849999999, 948.820007, 954.9600220000001, 969.5399779999999, 971.4699710000001, 975.8800050000001, 964.8599849999999, 966.9500119999999, 975.599976, 983.679993, 976.570007, 980.9400019999999, 983.409973, 949.830017, 942.900024, 953.400024, 950.76001, 942.3099980000001, 939.7800289999999, 957.3699949999999, 950.6300050000001, 959.4500119999999, 957.090027, 965.590027, 952.2700199999999, 927.330017, 940.48999, 917.7899779999999, 908.7299800000001, 898.7000119999999, 911.7100220000001, 906.6900019999999, 918.590027, 928.7999880000001, 930.090027, 943.830017, 947.159973, 955.98999, 953.419983, 965.400024, 970.8900150000001, 968.150024, 972.919983, 980.340027, 950.7000119999999, 947.7999880000001, 934.090027, 941.5300289999999, 930.5, 930.830017, 930.3900150000001, 923.650024, 927.9600220000001, 929.3599849999999, 926.7899779999999, 922.900024, 907.23999, 914.3900150000001, 922.669983, 922.2199710000001, 926.9600220000001, 910.9799800000001, 910.669983, 906.659973, 924.6900019999999, 927.0, 921.2800289999999, 915.8900150000001, 913.8099980000001, 921.2899779999999, 929.570007, 939.330017, 937.340027, 928.4500119999999, 927.8099980000001, 935.9500119999999, 926.5, 929.080017, 932.070007, 935.090027, 925.1099849999999, 920.2899779999999, 915.0, 921.8099980000001, 931.580017, 932.4500119999999, 928.5300289999999, 920.9699710000001, 924.8599849999999, 944.48999, 949.5, 959.1099849999999, 953.2700199999999, 957.7899779999999, 951.679993, 969.9600220000001, 978.8900150000001, 977.0, 972.599976, 989.25, 987.830017, 989.679993, 992.0, 992.179993, 992.8099980000001, 984.4500119999999, 988.2000119999999, 968.4500119999999, 970.5399779999999, 973.330017, 972.5599980000001, 1019.2700199999999, 1017.1099849999999, 1016.6400150000001, 1025.5, 1025.579956, 1032.47998, 1025.900024, 1033.329956, 1039.849976, 1031.26001, 1028.069946, 1025.75, 1026.0, 1020.909973, 1032.5, 1019.090027, 1018.3800050000001, 1034.48999, 1035.959961, 1040.609985, 1054.209961, 1047.410034, 1021.659973, 1021.409973, 1010.169983, 998.679993, 1005.150024, 1018.3800050000001, 1030.930054, 1037.050049, 1041.099976, 1040.47998, 1040.609985, 1049.150024, 1064.189941, 1077.140015, 1070.680054, 1064.949951, 1063.630005, 1060.119995, 1056.73999, 1049.369995, 1048.140015, 1046.400024, 1065.0, 1082.47998, 1086.400024, 1102.22998, 1106.939941, 1106.26001, 1102.609985, 1105.52002, 1122.26001, 1121.76001, 1131.97998, 1129.790039, 1137.51001, 1155.810059, 1169.969971, 1164.23999, 1170.369995, 1175.839966, 1175.579956, 1163.689941, 1169.939941, 1167.699951, 1111.900024, 1055.800049, 1080.599976, 1048.579956, 1001.5200199999999, 1037.780029, 1051.939941, 1052.099976, 1069.699 ...
# <div>
#
#
#             <div id="ae35cd1e-deb0-4b57-a301-48fd5ef13d8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ae35cd1e-deb0-4b57-a301-48fd5ef13d8c")) {
#                     Plotly.newPlot(
#                         'ae35cd1e-deb0-4b57-a301-48fd5ef13d8c',
#                         [{"line": {"color": "#0EB0F2"}, "name": "Open", "opacity": 0.8, "type": "scatter", "uid": "17ce2a10-1843-436e-9f65-396dc1709797", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "201 ...
# <div>
#
#
#             <div id="0dc04385-dfc5-4bcb-a739-ec30f7cba188" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0dc04385-dfc5-4bcb-a739-ec30f7cba188")) {
#                     Plotly.newPlot(
#                         '0dc04385-dfc5-4bcb-a739-ec30f7cba188',
#                         [{"line": {"color": "#17BECF"}, "name": "Rolling Mean", "opacity": 0.8, "type": "scatter", "uid": "afb3aadb-0113-4726-951e-8896596c3f08", "x": ["2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-26", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-24", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08", "2017-03-09", "2017-03-10", "2017-03-13", "2017-03-14", "2017-03-15", "2017-03-16", "2017-03-17", "2017-03-20", "2017-03-21", "2017-03-22", "2017-03-23", "2017-03-24", "2017-03-27", "2017-03-28", "2017-03-29", "2017-03-30", "2017-03-31", "2017-04-03", "2017-04-04", "2017-04-05", "2017-04-06", "2017-04-07", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-03", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-24", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-0 ...
# ******************************
# H0: Not Stationary
# H1: Stationary
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.881084
# p-value                          0.341011
# #Lags Used                      11.000000
# Number of Observations Used    490.000000
# Critical Value (1%)             -3.443766
# Critical Value (5%)             -2.867457
# Critical Value (10%)            -2.569921
# dtype: float64
# ******************************
# H0: Stationary
# H1: Not Stationary
# Results of KPSS Test:
# Test Statistic            2.168595
# p-value                   0.010000
# Lags Used                18.000000
# Critical Value (10%)      0.347000
# Critical Value (5%)       0.463000
# Critical Value (2.5%)     0.574000
# Critical Value (1%)       0.739000
# dtype: float64
# C:\Users\Ravi.RAVI-DRAGOON\Anaconda3\envs\tf-gpu\lib\site-packages\statsmodels\tsa\stattools.py:1276: InterpolationWarning:
#
# p-value is smaller than the indicated p-value

# %%
stock = googl['Close'].values.astype('float32')
stock = stock.reshape(502, 1)
stock.shape
# Out:
# (502, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
stock = scaler.fit_transform(stock)
train_size = int(len(stock) * 0.80)
test_size = len(stock) - train_size
train, test = stock[0:train_size,:], stock[train_size:len(stock),:]
print(len(train), len(test))
look_back = 7
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
(trainX.shape,trainY.shape),(testX.shape,testY.shape)
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1],1))
# Out:
# 401 101

# %%
model = Sequential()

model.add(LSTM(50, activation='relu', input_shape=(trainX.shape[1],1) ,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(100,activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50,activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(20,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='relu'))
model.summary()
model.compile(loss='mse', optimizer='rmsprop',metrics=['mse'])
history = model.fit(trainX,trainY,epochs=5,batch_size=7,validation_data=(testX,testY),shuffle=False)
pred = model.predict(testX)
plt.plot(testY)
plt.plot(pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 7, 50)             10400
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 7, 50)             0
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 7, 100)            60400
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 7, 100)            0
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 7, 50)             30200
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 7, 50)             0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 20)                5680
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 20)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 106,701
# Trainable params: 106,701
# Non-trainable params: 0
# _________________________________________________________________
# Train on 394 samples, validate on 94 samples
# Epoch 1/5
# 394/394 [==============================] - 8s 20ms/sample - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 2/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0350 - val_mean_squared_error: 0.0350
# Epoch 3/5
# 394/394 [==============================] - 5s 13ms/sample - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0725 - val_mean_squared_error: 0.0725
# Epoch 4/5
# 394/394 [==============================] - 5s 13ms/sample - loss: 0.0265 - mean_squared_error: 0.0265 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 5/5
# 394/394 [==============================] - 5s 12ms/sample - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
